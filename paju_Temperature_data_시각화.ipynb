# %% [markdown]
# <a href="https://colab.research.google.com/github/41915074/python/blob/main/paju_Temperature_data_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = 'http://apis.data.go.kr/1360000/AsosHourlyInfoService/getWthrDataList'
para ={'serviceKey' : 's9d24DID8McX9iHiTGEso0ztWsa4PWO7VTdsHYHrWLcLZWsVU8SWuuPHlsbg8/b0Zc80XqjGWuiP1Y+xKsxCzw==', 'pageNo' : '1', 'numOfRows' : '500', 'dataType' : 'JSON', 'dataCd' : 'ASOS', 'dateCd' : 'HR', 'startDt' : '20230101', 'startHh' : '01', 'endDt' : '20230501', 'endHh' : '01', 'stnIds' : '99' }

res = requests.get(url, params=para)
print(res.content)
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"tm":"2023-01-01 01:00","rnum":"1","stnId":"99","stnNm":"\xed\x8c\x8c\xec\xa3\xbc","ta":"-4.1","taQcflg":"","rn":"","rnQcflg":"","ws":"0.0","wsQcflg":"","wd":"0","wdQcflg":"","hm":"91","hmQcflg":"","pv":"4.1","td":"-5.3","pa":"1026.5","paQcflg":"","ps":"1030.5","psQcflg":"","ss":"","ssQcflg":"9","icsr":"","dsnw":"","hr3Fhsc":"","dc10Tca":"4","dc10LmcsCa":"4","clfmAbbrCd":"","lcsCh":"14","vs":"649","gndSttCd":"","dmstMtphNo":"","ts":"-2.1","tsQcflg":"","m005Te":"","m01Te":"","m02Te":"","m03Te":""},{"tm":"2023-01-01 02:00","rnum":"2","stnId":"99","stnNm":"\xed\x8c\x8c\xec\xa3\xbc","ta":"-5.0","taQcflg":"","rn":"","rnQcflg":"","ws":"0.7","wsQcflg":"","wd":"160","wdQcflg":"","hm":"93","hmQcflg":"","pv":"3.9","td":"-5.9","pa":"1026.4","paQcflg":"","ps":"1030.4","psQcflg":"","ss":"","ssQcflg":"9","icsr":"","dsnw":"","hr3Fhsc":"","dc10Tca":"0","dc10LmcsCa":"0","clfmAbbrCd":""
# ...

# %%
import json
json_file = json.loads(res.text)
json_file
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'},
#   'body': {'dataType': 'JSON',
#    'items': {'item': [{'tm': '2023-01-01 01:00',
#       'rnum': '1',
#       'stnId': '99',
#       'stnNm': '파주',
#       'ta': '-4.1',
#       'taQcflg': '',
#       'rn': '',
#       'rnQcflg': '',
#       'ws': '0.0',
#       'wsQcflg': '',
#       'wd': '0',
#       'wdQcflg': '',
#       'hm': '91',
#       'hmQcflg': '',
#       'pv': '4.1',
#       'td': '-5.3',
#       'pa': '1026.5',
#       'paQcflg': '',
#       'ps': '1030.5',
#       'psQcflg': '',
#       'ss': '',
#       'ssQcflg': '9',
#       'icsr': '',
#       'dsnw': '',
#       'hr3Fhsc': '',
#       'dc10Tca': '4',
#       'dc10LmcsCa': '4',
#       'clfmAbbrCd': '',
#       'lcsCh': '14',
#       'vs': '649',
#       'gndSttCd': '',
#       'dmstMtphNo': '',
#       'ts': '-2.1',
#       'tsQcflg': '',
#       'm005Te': '',
#       'm01Te': '',
#       'm02Te': '',
#       'm03Te': ''},
# ...

# %%
import pandas as pd
from pandas import json_normalize
df = json_normalize(json_file['response']['body']['items']['item'])

# %%
df
# Out:
#                    tm rnum stnId stnNm    ta taQcflg rn rnQcflg   ws wsQcflg  \
# 0    2023-01-01 01:00    1    99    파주  -4.1                     0.0
# 1    2023-01-01 02:00    2    99    파주  -5.0                     0.7
# 2    2023-01-01 03:00    3    99    파주  -6.5                     1.0
# 3    2023-01-01 04:00    4    99    파주  -6.5                     0.1
# 4    2023-01-01 05:00    5    99    파주  -7.0                     0.8
# ..                ...  ...   ...   ...   ...     ... ..     ...  ...     ...
# 495  2023-01-21 16:00  496    99    파주  -1.2                     0.6
# 496  2023-01-21 17:00  497    99    파주  -1.7                     0.2
# 497  2023-01-21 18:00  498    99    파주  -3.6                     0.0
# 498  2023-01-21 19:00  499    99    파주  -4.3                     0.2
# 499  2023-01-21 20:00  500    99    파주  -4.0                     0.0
#
#      ... lcsCh    vs gndSttCd dmstMtphNo    ts tsQcflg m005Te m01Te m02Te  \
# ...

# %%
df.to_excel(excel_writer="weather_list.xlsx")

# %%
import matplotlib.pyplot as plt


df['tm']=pd.to_datetime(df['tm'])
df['ta'] = pd.to_numeric(df['ta'], downcast='float')

fig = plt.figure(figsize=(14,6))
ax = plt.subplot(1,1,1)

ax.plot(df['tm'],df['ta'],color='r',lw=1.5,alpha=0.7)
ax.set_ylabel('Temperature', fontweight='bold', fontsize=12)
ax.set_xlabel('Date', fontweight='bold', fontsize=12)
ax.set_title('OPEN API ASOS Temperature data', fontweight = 'bold',fontsize = 14)
# Out:
# Text(0.5, 1.0, 'OPEN API ASOS Temperature data')
